# %%
from main.main_llm_and_fairness import MainLLMAndFairness

# %%
MainLLMAndFairness().start_the_system()
# Out:
# **Comportati come se fossi un esperto di data science e analisi dei dati. Il contesto è quello delle scienze sociali con attenzione alle questioni di bias e fairness.**
# Capito. Sono pronto a mettere a disposizione la mia expertise in data science e analisi dei dati, con un focus particolare sulle problematiche di bias e fairness, cruciali nelle scienze sociali. Fammi sapere come posso aiutarti oggi. Che tipo di analisi ti interessa? Hai un dataset specifico in mente, oppure vuoi discutere di tecniche per mitigare il bias in generale?
# **La mia variabile target è income. Non rispondere**
# Ok, ho capito che la tua variabile target è "income". Sono pronto ad assisterti nelle analisi che riguardano questa variabile.
# **Carica il mio dataset adult. Rispondi con il testo json {'tool_calls': [{'name': 'load_dataset', 'args': {'dataset_name': 'dset'}}]}. Sostituisci dset con il nome del mio dataset adult. Restituisci solo la stringa json senza alcuna formattazione ed altro testo.**
# ...
